# %% [markdown]
# <a href="https://colab.research.google.com/github/macfarlanestrategies/promptengineering/blob/main/StableDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# ...

# %%
# !pip install --upgrade diffusers transformers scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 112 kB 13.0 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 62.6 MB/s
# ...
#      |████████████████████████████████| 120 kB 56.7 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 32.1 MB/s
# ...

# %%
import huggingface_hub

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-2"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "a photo of an Arduino in Ukraine"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("arduino_ukraine.png")
# Out:
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/942 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/926 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/71.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/704 [00:00<?, ?B/s]
# ...

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-2"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "a photo of Vladimir Putin as Hitler in the movie Downfall"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Putin_downfall.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("putin_marilyn_monroe.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][10]  
    
image.save("putin_marilyn_monroe2.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "A watercolor painting of arrays of tensors"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=9.5)["sample"][0]  
    
image.save("tensors_watercolor2.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=5.5)["sample"][0]  
    
image.save("putin_marilyn_monroe3.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=8.5)["sample"][0]  
    
image.save("putin_marilyn_monroe4.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "A photo of Vladimir Putin as Marilyn Monroe in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=9.5)["sample"][0]  
    
image.save("putin_marilyn_monroe5.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "A photo of Vladimir Putin as Marilyn Monroe in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=3.5)["sample"][0]  
    
image.save("putin_marilyn_monroe6.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin's face in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=8.5)["sample"][0]  
    
image.save("putin_marilyn_monroe7.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "A painting of a Rasberry Pi Kubernetes Cluster"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=9.95)["sample"][0]  
    
image.save("kubernetescluster.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin reading the paper published by Google Brain named 'Attention Is All You Need'"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("putin_attention.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Putin reading the paper published by Google Brain named 'Attention Is All You Need' "
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Putin_attention2.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-2"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "a photo of Vladimir Putin as Hitler in the movie Downfall"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Putin_downfall2.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-2"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "a photo of Vladimir Putin as Hitler in the bunker in the movie Downfall"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Putin_downfall3.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-2"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "a photo of Vladimir Putin as Hitler in the movie Downfall"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Putin_downfall4.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "A photo of a drone charging at a Tesla EV charging station"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("electric_drone_tesla2.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin's face in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=8.5)["sample"][0]  
    
image.save("putin_marilyn_monroe9.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin's face in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=8.5)["sample"][0]  
    
image.save("putin_marilyn_monroe10.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "A watercolor portrait of a Kubernetes Cluster"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("kubernetes_watercolor.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Vladimir Putin's face in Marilyn Monroe’s Flying Skirt by Sam Shaw (1954)"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=8.5)["sample"][0]  
    
image.save("putin_marilyn_monroe14.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Ukrainian President Zelensky giving a speech about TinyML"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Zelensky_TinyML.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "Ukrainian President Zelensky learning about TinyML"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=7.5)["sample"][0]  
    
image.save("Zelensky_TinyML2.png")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# 0it [00:00, ?it/s]
